# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import load_dataset

mn_test = load_dataset("common_voice", "mn", split="test")
print(mn_test)

# %%
# Out:
# Python 3.12.13
